# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('saline_final_test.xlsx')
data.head(10)
# Out:
#      T_water  T_inside_glass  Ambient_Temperature  Irradiance  \
# 0  30.648048       42.261090            24.836431  503.677883
# 1  31.019030       42.782960            24.825085  503.673230
# 2  32.918222       44.330141            25.642509  532.695245
# 3  33.708846       45.065131            26.182776  551.631701
# 4  34.940351       46.238222            27.049364  581.997313
# 5  35.889947       47.121659            27.699846  604.631352
# 6  36.998516       48.316187            28.456220  631.131177
# 7  37.948112       48.316337            29.106701  641.412495
# 8  38.906297       47.528913            30.947931  658.090365
# 9  39.041981       47.381726            31.055984  654.376148
#
#    Hourly_Productivity  Mirror
# 0             0.000942       0
# 1             0.000941       0
# 2             0.000243       0
# 3             0.000239       0
# 4             0.000233       0
# 5             0.000132       0
# 6            -0.000660       0
# 7            -0.001402       0
# 8             0.009710       0
# 9             0.010500       0

# %%
data.shape
# Out:
# (370, 6)

# %%
data.describe()
# Out:
#           T_water  T_inside_glass  Ambient_Temperature  Irradiance  \
# count  370.000000      370.000000           370.000000  370.000000
# mean    43.030009       52.094492            31.967650  530.893491
# std      9.924879       12.128538             2.750258  261.670821
# min     28.138326       30.030097            22.613502   -9.384841
# 25%     33.621468       43.634037            30.176835  434.320077
# 50%     43.466377       49.681394            32.546772  601.877319
# 75%     50.929474       62.560178            33.854797  764.526140
# max     62.820060       70.876488            36.921123  847.031800
#
#        Hourly_Productivity      Mirror
# count           370.000000  370.000000
# mean              0.047259    1.997297
# std               0.041913    1.122566
# min              -0.002706    0.000000
# 25%               0.000806    1.000000
# 50%               0.040883    3.000000
# 75%               0.078343    3.000000
# max               0.138698    3.000000

# %%
len(data[data['Irradiance']<0])
# Out:
# 2

# %%
len(data[data['Hourly_Productivity']<0])
# Out:
# 31

# %%
data = data[data['Irradiance']>=0]

# %%
data[data<0] = 0

# %%
data.shape
# Out:
# (368, 6)

# %%
len(data[data['Hourly_Productivity']<0])
# Out:
# 0

# %%
data.shape
# Out:
# (368, 6)

# %%
data.describe()
# Out:
#           T_water  T_inside_glass  Ambient_Temperature  Irradiance  \
# count  368.000000      368.000000           368.000000  368.000000
# mean    43.078227       52.211389            31.989915  533.812990
# std      9.930181       12.056855             2.741018  259.352212
# min     28.138326       30.030097            22.613502    1.285918
# 25%     33.610863       43.739116            30.215247  438.745299
# 50%     43.531180       49.681394            32.574108  604.401911
# 75%     50.966114       62.611969            33.865284  764.593325
# max     62.820060       70.876488            36.921123  847.031800
#
#        Hourly_Productivity      Mirror
# count           368.000000  368.000000
# mean              0.047494    1.991848
# std               0.041879    1.123171
# min               0.000000    0.000000
# 25%               0.000768    1.000000
# 50%               0.041278    3.000000
# 75%               0.078442    3.000000
# max               0.138698    3.000000

# %%
import scipy

# %%
from scipy.stats import skew
print(skew(data,axis=0, bias=True))
# Out:
# [ 0.16157839  0.09635726 -1.04416203 -0.77632553  0.38645746 -0.50390937]

# %%
from scipy.stats import kurtosis
print(kurtosis(data,axis=0, bias=True))
# Out:
# [-1.27333738 -1.05097232  1.70254084 -0.77671518 -0.95598859 -1.29296868]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 0 to 367
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   T_water              368 non-null    float64
#  1   T_inside_glass       368 non-null    float64
#  2   Ambient_Temperature  368 non-null    float64
#  3   Irradiance           368 non-null    float64
#  4   Hourly_Productivity  368 non-null    float64
#  5   Mirror               368 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 20.1 KB

# %%
features_with_na = [features for features in data.columns if data[features].isnull().sum()>1]
print(len(features_with_na))
# Out:
# 0

# %%
print(data.corr())
dataplot = sns.heatmap(data.corr(), cmap="YlGnBu", annot=True)
plt.show()
# Out:
#                       T_water  T_inside_glass  Ambient_Temperature  \
# T_water              1.000000        0.834065             0.671587
# T_inside_glass       0.834065        1.000000             0.696288
# Ambient_Temperature  0.671587        0.696288             1.000000
# Irradiance           0.476190        0.811463             0.592725
# Hourly_Productivity  0.924453        0.642862             0.507940
# Mirror               0.401817        0.454503             0.246296
#
#                      Irradiance  Hourly_Productivity    Mirror
# T_water                0.476190             0.924453  0.401817
# T_inside_glass         0.811463             0.642862  0.454503
# Ambient_Temperature    0.592725             0.507940  0.246296
# Irradiance             1.000000             0.187925  0.123974
# Hourly_Productivity    0.187925             1.000000  0.443255
# Mirror                 0.123974             0.443255  1.000000

# %%
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(data, kind="scatter", hue="Hourly_Productivity", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
from scipy.stats import variation
variation(data)
# Out:
# array([0.23020168, 0.23060988, 0.08556731, 0.48518788, 0.88058501,
#        0.56311742])

# %% [markdown]
# ### Linear Regression

# %%
X = data[['T_water','T_inside_glass','Ambient_Temperature','Irradiance','Mirror']]
y = data['Hourly_Productivity']

# %%
import sys
sys.path.append('C:/Users/91905/AppData/Local/Programs/Python/Python311/Lib/site-packages')

# %%
from  sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 4.68557275e-03, -2.65633054e-04, -8.62265719e-04, -4.12856565e-05,
#         2.95018006e-03])

# %%
model.intercept_
# Out:
# -0.09690502329001688

# %%
y_pred_train = model.predict(X_train)

# %%
y_pred_test=model.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print('Mean Absolute Error testing:',metrics.mean_absolute_error(y_test,y_pred_test))
print('Mean Squared Error testing:',metrics.mean_squared_error(y_test,y_pred_test))
print('Root Mean Squared Error testing:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_test)))
# Out:
# Mean Absolute Error testing: 0.007397251749511455
# Mean Squared Error testing: 8.269485807390359e-05
# Root Mean Squared Error testing: 0.009093671319874257

# %%
print('Mean Absolute Error training:',metrics.mean_absolute_error(y_train,y_pred_train))
print('Mean Squared Error training:',metrics.mean_squared_error(y_train,y_pred_train))
print('Root Mean Squared Error training:',np.sqrt(metrics.mean_squared_error(y_train,y_pred_train)))
# Out:
# Mean Absolute Error training: 0.00847507756482186
# Mean Squared Error training: 0.00011148962278459556
# Root Mean Squared Error training: 0.010558864654147035

# %%
r2_testing = metrics.r2_score(y_test,y_pred_test)
r2_training = metrics.r2_score(y_train,y_pred_train)
print('R2 score training: ', metrics.r2_score(y_test,y_pred_test))

print('R2 score testing: ', metrics.r2_score(y_train,y_pred_train))
# Out:
# R2 score training:  0.9538169058738063
# R2 score testing:  0.9355940167371576

# %%
Adjusted_R2_training = 1 - (1-r2_training)*(X_train.shape[0]-1)/(X_train.shape[0]-5-1)
Adjusted_R2_testing = 1 - (1-r2_testing)*(X_test.shape[0]-1)/(X_test.shape[0]-5-1)
print('Adjusted R2 score training : ', Adjusted_R2_training)
print('Adjusted R2 score testing : ', Adjusted_R2_testing)
# Out:
# Adjusted R2 score training :  0.9343110290227583
# Adjusted R2 score testing :  0.9516177109154161

# %%
#Scatter for training data
# Residual plot for training data
plt.scatter(y_pred_train, y_train - y_pred_train, c='blue')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Training Data: Residual Plot")
plt.show()

# %%
# Residual plot for testing data
plt.scatter(y_pred_test, y_test - y_pred_test, c='blue')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Testing Data: Residual Plot")
plt.show()

# %%
# Histogram of residuals for training data
plt.hist(y_train - y_pred_train, bins=50, color='green')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Training Data: Histogram of Residuals")
plt.show()

# Histogram of residuals for testing data
plt.hist(y_test - y_pred_test, bins=50, color='orange')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Testing Data: Histogram of Residuals")
plt.show()

# %%
import scipy

# %%
# Q-Q plot for training data
residuals_train = y_train - y_pred_train
scipy.stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title("Training Data: Q-Q Plot")
plt.show()

# Q-Q plot for testing data
residuals_test = y_test - y_pred_test
scipy.stats.probplot(residuals_test, dist="norm", plot=plt)
plt.title("Testing Data: Q-Q Plot")
plt.show()

# %%
#percentage error graph
# calculate percentage error for testing data
percentage_error = 100 * np.abs(y_test - y_pred_test) / y_test

# plot percentage error
plt.figure(figsize=(8, 6))
plt.scatter(y_test, percentage_error, alpha=0.5)
plt.xlabel('Actual')
plt.ylabel('Percentage Error')
plt.title('Percentage Error vs Actual')
plt.show()

# %%
# # Learning curve
from sklearn.model_selection import learning_curve

# train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=10, scoring='neg_mean_squared_error')
# train_scores_mean = np.mean(-train_scores, axis=1)
# test_scores_mean = np.mean(-test_scores, axis=1)

# plt.plot(train_sizes, train_scores_mean, label='Training Error')
# plt.plot(train_sizes, test_scores_mean, label='Validation Error')
# plt.xlabel("Training Set Size")
# plt.ylabel("MSE")
# plt.title("Learning Curve")
# plt.legend()
# plt.show()

# assuming you have already defined your regression model as "model"
# and have loaded your dataset into "X" and "y"

# create learning curve with 5-fold cross-validation
train_sizes, train_scores, test_scores = learning_curve(
    estimator=model, X=X, y=y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# calculate mean and standard deviation of training and testing scores across folds
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Testing score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of training samples')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(7,7))
plt.scatter(y_test,y_pred_test,c='crimson')

p1 = min(min(y_pred_test),min(y_test))
p2 = max(max(y_pred_test),max(y_test))
plt.plot([p1,p2],[p1,p2],'b-')
plt.xlabel('True Values', fontsize = 15)
plt.ylabel('Predictions', fontsize = 15)
plt.axis('equal')
plt.axis('square')
plt.show()

# %%
import seaborn as sns
g = sns.lmplot(x='T_water', y='Hourly_Productivity',data = data,hue='Mirror')

# %% [markdown]
# ### Decision Tree Regression

# %%
X = data[['T_water','T_inside_glass','Ambient_Temperature','Irradiance','Mirror']]
y = data['Hourly_Productivity']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(criterion="friedman_mse",
                           max_depth=10,
                            min_samples_split=5,
                           random_state=5)

# %%
reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=10,
#                       min_samples_split=5, random_state=5)

# %%
y_pred_test = reg.predict(X_test)

# %%
y_pred_train = reg.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred_test)
# Out:
# 6.356277072600657e-05

# %%
print('Mean Absolute Error testing:',metrics.mean_absolute_error(y_test,y_pred_test))
print('Mean Squared Error testing:',metrics.mean_squared_error(y_test,y_pred_test))
print('Root Mean Squared Error testing:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_test)))
# Out:
# Mean Absolute Error testing: 0.003348098139354751
# Mean Squared Error testing: 6.356277072600657e-05
# Root Mean Squared Error testing: 0.007972626338039841

# %%
print('Mean Absolute Error training:',metrics.mean_absolute_error(y_train,y_pred_train))
print('Mean Squared Error training:',metrics.mean_squared_error(y_train,y_pred_train))
print('Root Mean Squared Error training:',np.sqrt(metrics.mean_squared_error(y_train,y_pred_train)))
# Out:
# Mean Absolute Error training: 0.0010579337607893088
# Mean Squared Error training: 4.459395915128936e-06
# Root Mean Squared Error training: 0.002111728182112683

# %%
r2_testing = metrics.r2_score(y_test,y_pred_test)
r2_training = metrics.r2_score(y_train,y_pred_train)
print('R2 score training: ', metrics.r2_score(y_test,y_pred_test))
print('R2 score testing: ', metrics.r2_score(y_train,y_pred_train))

Adjusted_R2_training = 1 - (1-r2_training)*(X_train.shape[0]-1)/(X_train.shape[0]-5-1)
Adjusted_R2_testing = 1 - (1-r2_testing)*(X_test.shape[0]-1)/(X_test.shape[0]-5-1)
print('Adjusted R2 score training : ', Adjusted_R2_training)
print('Adjusted R2 score testing : ', Adjusted_R2_testing)
# Out:
# R2 score training:  0.96450171761904
# R2 score testing:  0.9974238698499582
# Adjusted R2 score training :  0.9973725525162921
# Adjusted R2 score testing :  0.9628113232199467

# %%
from sklearn import tree
text_representation = tree.export_text(reg)
print(text_representation)
# Out:
# |--- feature_0 <= 42.24
# |   |--- feature_1 <= 40.06
# |   |   |--- feature_4 <= 2.50
# |   |   |   |--- feature_3 <= 83.51
# |   |   |   |   |--- feature_2 <= 29.60
# |   |   |   |   |   |--- feature_2 <= 28.47
# |   |   |   |   |   |   |--- feature_3 <= 9.51
# |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- feature_3 >  9.51
# |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |--- feature_2 >  28.47
# |   |   |   |   |   |   |--- feature_0 <= 34.14
# |   |   |   |   |   |   |   |--- feature_2 <= 28.74
# |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |--- feature_2 >  28.74
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- feature_0 >  34.14
# |   |   |   |   |   |   |   |--- feature_1 <= 31.86
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |--- feature_1 >  31.86
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |--- feature_2 >  29.60
# |   |   |   |   |   |--- feature_1 <= 33.25
# |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |--- feature_1 >  33.25
# |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |--- feature_3 >  83.51
# |   |   |   |   |--- feature_2 <= 22.76
# |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |--- feature_2 >  22.76
# |   |   |   |   |   |--- feature_1 <= 35.29
# |   |   |   |   |   |   |--- feature_2 <= 22.87
# |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |--- feature_2 >  22.87
# |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |--- feature_1 >  35.29
# |   |   |   |   |   |   |--- value: [0.04]
# |   |   |--- feature_4 >  2.50
# |   |   |   |--- value: [0.06]
# |   |--- feature_1 >  40.06
# |   |   |--- feature_0 <= 39.90
# |   |   |   |--- feature_0 <= 37.95
# |   |   |   |   |--- feature_3 <= 668.68
# |   |   |   |   |   |--- feature_2 <= 29.65
# |   |   |   |   |   |   |--- feature_2 <= 29.59
# |   |   |   |   |   |   |   |--- feature_2 <= 29.54
# |   |   |   |   |   |   |   |   |--- feature_2 <= 27.98
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 32.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  32.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  27.98
# |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- feature_2 >  29.54
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- feature_2 >  29.59
# |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |--- feature_2 >  29.65
# |   |   |   |   |   |   |--- feature_1 <= 46.19
# |   |   |   |   |   |   |   |--- feature_0 <= 33.09
# |   |   |   |   |   |   |   |   |--- feature_4 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 489.96
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  489.96
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  2.00
# |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- feature_0 >  33.09
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- feature_1 >  46.19
# |   |   |   |   |   |   |   |--- feature_3 <= 547.14
# |   |   |   |   |   |   |   |   |--- feature_1 <= 47.75
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 524.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  524.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |--- feature_1 >  47.75
# |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- feature_3 >  547.14
# |   |   |   |   |   |   |   |   |--- feature_2 <= 32.84
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 49.42
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  49.42
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  32.84
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 647.47
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  647.47
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |--- feature_3 >  668.68
# |   |   |   |   |   |--- value: [0.00]
# |   |   |   |--- feature_0 >  37.95
# |   |   |   |   |--- value: [0.01]
# |   |   |--- feature_0 >  39.90
# |   |   |   |--- value: [0.03]
# |--- feature_0 >  42.24
# |   |--- feature_0 <= 56.25
# |   |   |--- feature_3 <= 462.72
# |   |   |   |--- feature_3 <= 209.30
# |   |   |   |   |--- feature_3 <= 195.93
# |   |   |   |   |   |--- feature_0 <= 43.89
# |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |--- feature_0 >  43.89
# |   |   |   |   |   |   |--- feature_1 <= 48.97
# |   |   |   |   |   |   |   |--- feature_3 <= 166.91
# |   |   |   |   |   |   |   |   |--- feature_3 <= 151.32
# |   |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |   |--- feature_3 >  151.32
# |   |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |--- feature_3 >  166.91
# |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |--- feature_1 >  48.97
# |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |--- feature_3 >  195.93
# |   |   |   |   |   |--- value: [0.09]
# |   |   |   |--- feature_3 >  209.30
# |   |   |   |   |--- feature_3 <= 232.12
# |   |   |   |   |   |--- feature_3 <= 222.67
# |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |--- feature_3 >  222.67
# |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |--- feature_3 >  232.12
# |   |   |   |   |   |--- feature_3 <= 249.41
# |   |   |   |   |   |   |--- feature_0 <= 44.11
# |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |   |--- feature_0 >  44.11
# |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |--- feature_3 >  249.41
# |   |   |   |   |   |   |--- value: [0.10]
# |   |   |--- feature_3 >  462.72
# |   |   |   |--- feature_0 <= 47.98
# |   |   |   |   |--- feature_3 <= 733.91
# |   |   |   |   |   |--- feature_1 <= 44.81
# |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |--- feature_1 >  44.81
# |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |--- feature_3 >  733.91
# |   |   |   |   |   |--- feature_3 <= 754.53
# |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |   |   |--- feature_3 >  754.53
# |   |   |   |   |   |   |--- feature_0 <= 47.08
# |   |   |   |   |   |   |   |--- feature_1 <= 61.93
# |   |   |   |   |   |   |   |   |--- feature_1 <= 61.65
# |   |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |   |--- feature_1 >  61.65
# |   |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |--- feature_1 >  61.93
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- feature_0 >  47.08
# |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |--- feature_0 >  47.98
# |   |   |   |   |--- feature_3 <= 724.44
# |   |   |   |   |   |--- feature_0 <= 53.51
# |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |--- feature_0 >  53.51
# |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |--- feature_3 >  724.44
# |   |   |   |   |   |--- feature_0 <= 49.58
# |   |   |   |   |   |   |--- feature_1 <= 52.42
# |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |   |   |   |--- feature_1 >  52.42
# |   |   |   |   |   |   |   |--- feature_2 <= 33.64
# |   |   |   |   |   |   |   |   |--- feature_1 <= 61.35
# |   |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |   |   |--- feature_1 >  61.35
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 735.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  735.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |--- feature_2 >  33.64
# |   |   |   |   |   |   |   |   |--- feature_0 <= 48.76
# |   |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |   |   |--- feature_0 >  48.76
# |   |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |--- feature_0 >  49.58
# |   |   |   |   |   |   |--- feature_2 <= 36.65
# |   |   |   |   |   |   |   |--- feature_3 <= 786.53
# |   |   |   |   |   |   |   |   |--- feature_0 <= 53.75
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 50.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  50.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |--- feature_0 >  53.75
# |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |--- feature_3 >  786.53
# |   |   |   |   |   |   |   |   |--- feature_1 <= 69.37
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 797.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  797.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |   |   |--- feature_1 >  69.37
# |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |--- feature_2 >  36.65
# |   |   |   |   |   |   |   |--- value: [0.09]
# |   |--- feature_0 >  56.25
# |   |   |--- feature_2 <= 33.82
# |   |   |   |--- feature_2 <= 33.37
# |   |   |   |   |--- feature_1 <= 70.54
# |   |   |   |   |   |--- feature_1 <= 70.27
# |   |   |   |   |   |   |--- feature_2 <= 33.25
# |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |--- feature_2 >  33.25
# |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |--- feature_1 >  70.27
# |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |--- feature_1 >  70.54
# |   |   |   |   |   |--- value: [0.13]
# |   |   |   |--- feature_2 >  33.37
# |   |   |   |   |--- feature_0 <= 58.40
# |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |--- feature_0 >  58.40
# |   |   |   |   |   |--- value: [0.13]
# |   |   |--- feature_2 >  33.82
# |   |   |   |--- feature_3 <= 776.60
# |   |   |   |   |--- feature_3 <= 768.93
# |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |--- feature_3 >  768.93
# |   |   |   |   |   |--- feature_2 <= 34.15
# |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |--- feature_2 >  34.15
# |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |--- feature_3 >  776.60
# |   |   |   |   |--- feature_3 <= 787.07
# |   |   |   |   |   |--- feature_3 <= 782.13
# |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |--- feature_3 >  782.13
# |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |--- feature_3 >  787.07
# |   |   |   |   |   |--- value: [0.08]

# %%
fig = plt.figure(figsize=(30,15))
_ = tree.plot_tree(reg, feature_names=X.columns, filled=True)

# %%
#Scatter for training data
# Residual plot for training data
plt.scatter(y_pred_train, y_train - y_pred_train, c='green')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Training Data: Residual Plot")
plt.show()

# Residual plot for testing data
plt.scatter(y_pred_test, y_test - y_pred_test, c='green')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Testing Data: Residual Plot")
plt.show()

# %%
# Histogram of residuals for training data
plt.hist(y_train - y_pred_train, bins=50, color='green')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Training Data: Histogram of Residuals")
plt.show()

# Histogram of residuals for testing data
plt.hist(y_test - y_pred_test, bins=50, color='orange')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Testing Data: Histogram of Residuals")
plt.show()

# %%
# Q-Q plot for training data
residuals_train = y_train - y_pred_train
scipy.stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title("Training Data: Q-Q Plot")
plt.show()

# Q-Q plot for testing data
residuals_test = y_test - y_pred_test
scipy.stats.probplot(residuals_test, dist="norm", plot=plt)
plt.title("Testing Data: Q-Q Plot")
plt.show()

# %%
#percentage error graph
# calculate percentage error for testing data
percentage_error = 100 * np.abs(y_test - y_pred_test) / y_test

# plot percentage error
plt.figure(figsize=(8, 6))
plt.scatter(y_test, percentage_error, alpha=0.5)
plt.xlabel('Actual')
plt.ylabel('Percentage Error')
plt.title('Percentage Error vs Actual')
plt.show()

# %%
# # Learning curve
# from sklearn.model_selection import learning_curve

# train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=10, scoring='neg_mean_squared_error')
# train_scores_mean = np.mean(-train_scores, axis=1)
# test_scores_mean = np.mean(-test_scores, axis=1)

# plt.plot(train_sizes, train_scores_mean, label='Training Error')
# plt.plot(train_sizes, test_scores_mean, label='Validation Error')
# plt.xlabel("Training Set Size")
# plt.ylabel("MSE")
# plt.title("Learning Curve")
# plt.legend()
# plt.show()

# assuming you have already defined your regression model as "model"
# and have loaded your dataset into "X" and "y"

# create learning curve with 5-fold cross-validation
train_sizes, train_scores, test_scores = learning_curve(
    estimator=reg, X=X, y=y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# calculate mean and standard deviation of training and testing scores across folds
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Testing score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of training samples')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(7,7))
plt.scatter(y_test,y_pred_test,c='crimson')

p1 = min(min(y_pred_test),min(y_test))
p2 = max(max(y_pred_test),max(y_test))
plt.plot([p1,p2],[p1,p2],'y-')
plt.xlabel('True Values', fontsize = 15)
plt.ylabel('Predictions', fontsize = 15)
plt.axis('equal')
plt.axis('square')
plt.show()

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
X = data[['T_water','T_inside_glass','Ambient_Temperature','Irradiance','Mirror']]
y = data['Hourly_Productivity']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
rf = RandomForestRegressor(n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features='sqrt', max_depth=20, bootstrap=True, random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=20, max_features='sqrt', n_estimators=1000,
#                       random_state=42)

# %%
y_pred_test = rf.predict(X_test)
y_pred_train = rf.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mean_squared_error(y_test,y_pred_test)
# Out:
# 1.1963654540472492e-05

# %%
print('Mean Absolute Error testing:',metrics.mean_absolute_error(y_test,y_pred_test))
print('Mean Squared Error testing:',metrics.mean_squared_error(y_test,y_pred_test))
print('Root Mean Squared Error testing:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_test)))
print()
print()
print('Mean Absolute Error training:',metrics.mean_absolute_error(y_train,y_pred_train))
print('Mean Squared Error training:',metrics.mean_squared_error(y_train,y_pred_train))
print('Root Mean Squared Error training:',np.sqrt(metrics.mean_squared_error(y_train,y_pred_train)))
# Out:
# Mean Absolute Error testing: 0.0018949449829929513
# Mean Squared Error testing: 1.1963654540472492e-05
# Root Mean Squared Error testing: 0.003458851621632893
#
#
# Mean Absolute Error training: 0.001017562814059094
# Mean Squared Error training: 4.7926399838834015e-06
# Root Mean Squared Error training: 0.0021892098994576565

# %%
r2_testing = metrics.r2_score(y_test,y_pred_test)
r2_training = metrics.r2_score(y_train,y_pred_train)
print('R2 score training: ', metrics.r2_score(y_test,y_pred_test))
print('R2 score testing: ', metrics.r2_score(y_train,y_pred_train))

Adjusted_R2_training = 1 - (1-r2_training)*(X_train.shape[0]-1)/(X_train.shape[0]-5-1)
Adjusted_R2_testing = 1 - (1-r2_testing)*(X_test.shape[0]-1)/(X_test.shape[0]-5-1)
print('Adjusted R2 score training : ', Adjusted_R2_training)
print('Adjusted R2 score testing : ', Adjusted_R2_testing)
# Out:
# R2 score training:  0.9933185859846071
# R2 score testing:  0.9972313594496306
# Adjusted R2 score training :  0.9971762072474321
# Adjusted R2 score testing :  0.9930004234124455

# %%
#Scatter for training data
# Residual plot for training data
plt.scatter(y_pred_train, y_train - y_pred_train, c='crimson')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Training Data: Residual Plot")
plt.show()

# Residual plot for testing data
plt.scatter(y_pred_test, y_test - y_pred_test, c='crimson')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Testing Data: Residual Plot")
plt.show()

# %%
# Histogram of residuals for training data
plt.hist(y_train - y_pred_train, bins=50, color='red')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Training Data: Histogram of Residuals")
plt.show()

# Histogram of residuals for testing data
plt.hist(y_test - y_pred_test, bins=50, color='green')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Testing Data: Histogram of Residuals")
plt.show()

# %%
# Q-Q plot for training data
residuals_train = y_train - y_pred_train
scipy.stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title("Training Data: Q-Q Plot")
plt.show()

# Q-Q plot for testing data
residuals_test = y_test - y_pred_test
scipy.stats.probplot(residuals_test, dist="norm", plot=plt)
plt.title("Testing Data: Q-Q Plot")
plt.show()

# %%
# create learning curve with 5-fold cross-validation
train_sizes, train_scores, test_scores = learning_curve(
    estimator=rf, X=X, y=y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# calculate mean and standard deviation of training and testing scores across folds
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_mean, color='red', marker='o', markersize=5, label='Training score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Testing score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of training samples')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(7,7))
plt.scatter(y_test,y_pred_test,c='crimson')

p1 = min(min(y_pred_test),min(y_test))
p2 = max(max(y_pred_test),max(y_test))
plt.plot([p1,p2],[p1,p2],'b-')
plt.xlabel('True Values', fontsize = 15)
plt.ylabel('Predictions', fontsize = 15)
plt.axis('equal')
plt.axis('square')
plt.show()

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
data
# Out:
#        T_water  T_inside_glass  Ambient_Temperature  Irradiance  \
# 0    30.648048       42.261090            24.836431  503.677883
# 1    31.019030       42.782960            24.825085  503.673230
# 2    32.918222       44.330141            25.642509  532.695245
# 3    33.708846       45.065131            26.182776  551.631701
# 4    34.940351       46.238222            27.049364  581.997313
# ..         ...             ...                  ...         ...
# 363  42.063907       42.800097            31.734176   54.004777
# 364  41.882302       42.562341            31.681390   78.314768
# 365  41.891860       39.947029            30.913158   70.969142
# 366  40.388037       38.439829            30.041238   36.133406
# 367  36.602992       32.702559            28.946861   30.825743
#
#      Hourly_Productivity  Mirror
# 0               0.000942       0
# 1               0.000941       0
# 2               0.000243       0
# 3               0.000239       0
# 4               0.000233       0
# ..                   ...     ...
# 363             0.073506       3
# 364             0.072720       3
# 365             0.063867       3
# 366             0.057933       3
# 367             0.061245       3
#
# [368 rows x 6 columns]

# %%
X = data[['T_water','T_inside_glass','Ambient_Temperature','Irradiance','Mirror']]
y = data['Hourly_Productivity']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
gb = GradientBoostingRegressor(random_state=42)

# %%
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
import pickle
pickle.dump(gb, open('./model.sav', 'wb'))

# %%
y_pred_test = gb.predict(X_test)
y_pred_train = gb.predict(X_train)

# %%
from sklearn import metrics
print('Mean Absolute Error testing:',metrics.mean_absolute_error(y_test,y_pred_test))
print('Mean Squared Error testing:',metrics.mean_squared_error(y_test,y_pred_test))
print('Root Mean Squared Error testing:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_test)))
print()
print()
print('Mean Absolute Error training:',metrics.mean_absolute_error(y_train,y_pred_train))
print('Mean Squared Error training:',metrics.mean_squared_error(y_train,y_pred_train))
print('Root Mean Squared Error training:',np.sqrt(metrics.mean_squared_error(y_train,y_pred_train)))
# Out:
# Mean Absolute Error testing: 0.002193743178187174
# Mean Squared Error testing: 1.340901677343957e-05
# Root Mean Squared Error testing: 0.003661832433828666
#
#
# Mean Absolute Error training: 0.0010848804170948319
# Mean Squared Error training: 2.3693013509658356e-06
# Root Mean Squared Error training: 0.0015392535044513739

# %%
r2_testing = metrics.r2_score(y_test,y_pred_test)
r2_training = metrics.r2_score(y_train,y_pred_train)
print('R2 score training: ', metrics.r2_score(y_test,y_pred_test))
print('R2 score testing: ', metrics.r2_score(y_train,y_pred_train))

Adjusted_R2_training = 1 - (1-r2_training)*(X_train.shape[0]-1)/(X_train.shape[0]-5-1)
Adjusted_R2_testing = 1 - (1-r2_testing)*(X_test.shape[0]-1)/(X_test.shape[0]-5-1)
print('Adjusted R2 score training : ', Adjusted_R2_training)
print('Adjusted R2 score testing : ', Adjusted_R2_testing)
# Out:
# R2 score training:  0.992511385856252
# R2 score testing:  0.9986312880127888
# Adjusted R2 score training :  0.9986040228337607
# Adjusted R2 score testing :  0.9921547851827401

# %%
#Scatter for training data
# Residual plot for training data
plt.scatter(y_pred_train, y_train - y_pred_train, c='green')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Training Data: Residual Plot")
plt.show()

# Residual plot for testing data
plt.scatter(y_pred_test, y_test - y_pred_test, c='green')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Testing Data: Residual Plot")
plt.show()

# %%
# Histogram of residuals for training data
plt.hist(y_train - y_pred_train, bins=50, color='red')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Training Data: Histogram of Residuals")
plt.show()

# Histogram of residuals for testing data
plt.hist(y_test - y_pred_test, bins=50, color='black')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Testing Data: Histogram of Residuals")
plt.show()

# %%
# Q-Q plot for training data
residuals_train = y_train - y_pred_train
scipy.stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title("Training Data: Q-Q Plot")
plt.show()

# Q-Q plot for testing data
residuals_test = y_test - y_pred_test
scipy.stats.probplot(residuals_test, dist="norm", plot=plt)
plt.title("Testing Data: Q-Q Plot")
plt.show()

# %%
# # Learning curve
# from sklearn.model_selection import learning_curve

# train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=10, scoring='neg_mean_squared_error')
# train_scores_mean = np.mean(-train_scores, axis=1)
# test_scores_mean = np.mean(-test_scores, axis=1)

# plt.plot(train_sizes, train_scores_mean, label='Training Error')
# plt.plot(train_sizes, test_scores_mean, label='Validation Error')
# plt.xlabel("Training Set Size")
# plt.ylabel("MSE")
# plt.title("Learning Curve")
# plt.legend()
# plt.show()

# assuming you have already defined your regression model as "model"
# and have loaded your dataset into "X" and "y"

# create learning curve with 5-fold cross-validation
train_sizes, train_scores, test_scores = learning_curve(
    estimator=gb, X=X, y=y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# calculate mean and standard deviation of training and testing scores across folds
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# plot learning curve
plt.figure(figsize=(8,6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Testing score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of training samples')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(7,7))
plt.scatter(y_test,y_pred_test,c='red')

p1 = min(min(y_pred_test),min(y_test))
p2 = max(max(y_pred_test),max(y_test))
plt.plot([p1,p2],[p1,p2],'b-')
plt.xlabel('True Values', fontsize = 15)
plt.ylabel('Predictions', fontsize = 15)
plt.axis('equal')
plt.axis('square')
plt.show()

# %% [markdown]
# ### Support Vector Regression

# %%
scaled_data = (data - data.min()) / (data.max() - data.min())

# %%
scaled_data.head()
# Out:
#     T_water  T_inside_glass  Ambient_Temperature  Irradiance  \
# 0  0.072364        0.299439             0.155367    0.594022
# 1  0.083061        0.312215             0.154574    0.594017
# 2  0.137822        0.350093             0.211706    0.628332
# 3  0.160618        0.368087             0.249467    0.650722
# 4  0.196127        0.396807             0.310035    0.686626
#
#    Hourly_Productivity  Mirror
# 0             0.006792     0.0
# 1             0.006786     0.0
# 2             0.001755     0.0
# 3             0.001726     0.0
# 4             0.001678     0.0

# %%
X = scaled_data[['T_water','T_inside_glass','Ambient_Temperature','Irradiance','Mirror']]
y = scaled_data['Hourly_Productivity']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn import svm

# %%
svr = svm.SVR()

# %%
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_pred_test = svr.predict(X_test)
y_pred_train = svr.predict(X_train)

# %%
print('Mean Absolute Error testing:',metrics.mean_absolute_error(y_test,y_pred_test))
print('Mean Squared Error testing:',metrics.mean_squared_error(y_test,y_pred_test))
print('Root Mean Squared Error testing:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_test)))
print()
print()
print('Mean Absolute Error training:',metrics.mean_absolute_error(y_train,y_pred_train))
print('Mean Squared Error training:',metrics.mean_squared_error(y_train,y_pred_train))
print('Root Mean Squared Error training:',np.sqrt(metrics.mean_squared_error(y_train,y_pred_train)))
# Out:
# Mean Absolute Error testing: 0.05586266652313816
# Mean Squared Error testing: 0.0038634338331275902
# Root Mean Squared Error testing: 0.0621565268747184
#
#
# Mean Absolute Error training: 0.06341440322271716
# Mean Squared Error training: 0.004892082625291774
# Root Mean Squared Error training: 0.0699434244607152

# %%
r2_testing = metrics.r2_score(y_test,y_pred_test)
r2_training = metrics.r2_score(y_train,y_pred_train)
print('R2 score training: ', metrics.r2_score(y_test,y_pred_test))
print('R2 score testing: ', metrics.r2_score(y_train,y_pred_train))

Adjusted_R2_training = 1 - (1-r2_training)*(X_train.shape[0]-1)/(X_train.shape[0]-5-1)
Adjusted_R2_testing = 1 - (1-r2_testing)*(X_test.shape[0]-1)/(X_test.shape[0]-5-1)
print('Adjusted R2 score training : ', Adjusted_R2_training)
print('Adjusted R2 score testing : ', Adjusted_R2_testing)
# Out:
# R2 score training:  0.9584930755456715
# R2 score testing:  0.9456339089260063
# Adjusted R2 score training :  0.9445509190639746
# Adjusted R2 score testing :  0.9565165553335606

# %%
#Scatter for training data
# Residual plot for training data
plt.scatter(y_pred_train, y_train - y_pred_train, c='blue')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Training Data: Residual Plot")
plt.show()

# Residual plot for testing data
plt.scatter(y_pred_test, y_test - y_pred_test, c='blue')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Testing Data: Residual Plot")
plt.show()

# %%
# Histogram of residuals for training data
plt.hist(y_train - y_pred_train, bins=50, color='blue')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Training Data: Histogram of Residuals")
plt.show()

# Histogram of residuals for testing data
plt.hist(y_test - y_pred_test, bins=50, color='orange')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Testing Data: Histogram of Residuals")
plt.show()

# %%
# Q-Q plot for training data
residuals_train = y_train - y_pred_train
scipy.stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title("Training Data: Q-Q Plot")
plt.show()

# Q-Q plot for testing data
residuals_test = y_test - y_pred_test
scipy.stats.probplot(residuals_test, dist="norm", plot=plt)
plt.title("Testing Data: Q-Q Plot")
plt.show()

# %%
# # Learning curve
# from sklearn.model_selection import learning_curve

# train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=10, scoring='neg_mean_squared_error')
# train_scores_mean = np.mean(-train_scores, axis=1)
# test_scores_mean = np.mean(-test_scores, axis=1)

# plt.plot(train_sizes, train_scores_mean, label='Training Error')
# plt.plot(train_sizes, test_scores_mean, label='Validation Error')
# plt.xlabel("Training Set Size")
# plt.ylabel("MSE")
# plt.title("Learning Curve")
# plt.legend()
# plt.show()

# assuming you have already defined your regression model as "model"
# and have loaded your dataset into "X" and "y"

# create learning curve with 5-fold cross-validation
train_sizes, train_scores, test_scores = learning_curve(
    estimator=svr, X=X, y=y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# calculate mean and standard deviation of training and testing scores across folds
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Testing score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of training samples')
plt.ylabel('Score')
plt.title('Learning Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(7,7))
plt.scatter(y_test,y_pred_test,c='crimson')

p1 = min(min(y_pred_test),min(y_test))
p2 = max(max(y_pred_test),max(y_test))
plt.plot([p1,p2],[p1,p2],'b-')
plt.xlabel('True Values', fontsize = 15)
plt.ylabel('Predictions', fontsize = 15)
plt.axis('equal')
plt.axis('square')
plt.show()

# %% [markdown]
# ## ANN

# %%
X = data[['T_water','T_inside_glass','Ambient_Temperature','Irradiance','Mirror']]
y = data['Hourly_Productivity']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# !pip install keras
# !pip install tensorflow
from keras import Sequential
from keras.layers import Dense
# Out:
# Requirement already satisfied: keras in c:\users\divya\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow in c:\users\divya\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: setuptools in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: packaging in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.53.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: six>=1.12.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\divya\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\divya\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\divya\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\divya\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.0.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\divya\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\divya\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\divya\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\divya\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\divya\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\divya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\divya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\divya\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\divya\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\divya\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
model = Sequential()
model.add(Dense(128, input_dim=5, activation="relu"))
model.add(Dense(64,activation="relu"))
model.add(Dense(1,activation="linear"))

# %%
model.compile(loss="mean_squared_error", optimizer="adam", metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,089
# Trainable params: 9,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 92ms/step - loss: 0.0264 - mae: 0.1234 - val_loss: 0.0145 - val_mae: 0.1027
# Epoch 2/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0059 - mae: 0.0596 - val_loss: 0.0058 - val_mae: 0.0620
# Epoch 3/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0039 - mae: 0.0502 - val_loss: 0.0015 - val_mae: 0.0318
# Epoch 4/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0016 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0306
# Epoch 5/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0012 - mae: 0.0266 - val_loss: 6.7838e-04 - val_mae: 0.0203
# Epoch 6/100
# 7/7 [==============================] - 0s 17ms/step - loss: 4.9966e-04 - mae: 0.0176 - val_loss: 3.8728e-04 - val_mae: 0.0166
# Epoch 7/100
# 7/7 [==============================] - 0s 18ms/step - loss: 3.5480e-04 - mae: 0.0144 - val_loss: 2.3424e-04 - val_mae: 0.0130
# Epoch 8/100
# 7/7 [==============================] - 0s 15ms/step - loss: 2.4191e-04 - mae: 0.0123 - val_loss: 1.9117e-04 - val_mae: 0.0119
# Epoch 9/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.7188e-04 - mae: 0.0106 - val_loss: 1.0765e-04 - val_mae: 0.0085
# Epoch 10/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0889e-04 - mae: 0.0080 - val_loss: 9.5166e-05 - val_mae: 0.0077
# Epoch 11/100
# 7/7 [==============================] - 0s 19ms/step - loss: 7.8906e-05 - mae: 0.0065 - val_loss: 8.8310e-05 - val_mae: 0.0078
# Epoch 12/100
# 7/7 [==============================] - 0s 21ms/step - loss: 6.9086e-05 - mae: 0.0061 - val_loss: 7.7728e-05 - val_mae: 0.0071
# Epoch 13/100
# 7/7 [==============================] - 0s 19ms/step - loss: 5.5239e-05 - mae: 0.0052 - val_loss: 6.1061e-05 - val_mae: 0.0060
# Epoch 14/100
# 7/7 [==============================] - 0s 23ms/step - loss: 4.9843e-05 - mae: 0.0050 - val_loss: 5.4905e-05 - val_mae: 0.0057
# Epoch 15/100
# 7/7 [==============================] - 0s 17ms/step - loss: 4.3231e-05 - mae: 0.0046 - val_loss: 5.5836e-05 - val_mae: 0.0055
# Epoch 16/100
# 7/7 [==============================] - 0s 19ms/step - loss: 3.9351e-05 - mae: 0.0042 - val_loss: 4.7195e-05 - val_mae: 0.0050
# Epoch 17/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.9229e-05 - mae: 0.0044 - val_loss: 5.4145e-05 - val_mae: 0.0055
# Epoch 18/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.5788e-05 - mae: 0.0042 - val_loss: 4.8234e-05 - val_mae: 0.0050
# Epoch 19/100
# 7/7 [==============================] - 0s 23ms/step - loss: 3.3072e-05 - mae: 0.0040 - val_loss: 3.9462e-05 - val_mae: 0.0043
# Epoch 20/100
# 7/7 [==============================] - 0s 19ms/step - loss: 3.2293e-05 - mae: 0.0039 - val_loss: 4.0360e-05 - val_mae: 0.0045
# Epoch 21/100
# 7/7 [==============================] - 0s 21ms/step - loss: 2.9597e-05 - mae: 0.0038 - val_loss: 3.9620e-05 - val_mae: 0.0043
# Epoch 22/100
# 7/7 [==============================] - 0s 18ms/step - loss: 2.6960e-05 - mae: 0.0036 - val_loss: 4.1998e-05 - val_mae: 0.0048
# Epoch 23/100
# 7/7 [==============================] - 0s 15ms/step - loss: 2.6919e-05 - mae: 0.0036 - val_loss: 3.6284e-05 - val_mae: 0.0041
# Epoch 24/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2.4600e-05 - mae: 0.0033 - val_loss: 3.4093e-05 - val_mae: 0.0040
# Epoch 25/100
# 7/7 [==============================] - 0s 18ms/step - loss: 2.5101e-05 - mae: 0.0035 - val_loss: 3.4557e-05 - val_mae: 0.0040
# Epoch 26/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.4657e-05 - mae: 0.0035 - val_loss: 3.6133e-05 - val_mae: 0.0045
# Epoch 27/100
# 7/7 [==============================] - 0s 21ms/step - loss: 2.9935e-05 - mae: 0.0039 - val_loss: 3.3661e-05 - val_mae: 0.0040
# Epoch 28/100
# 7/7 [==============================] - 0s 21ms/step - loss: 2.7532e-05 - mae: 0.0036 - val_loss: 4.5614e-05 - val_mae: 0.0048
# Epoch 29/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.5343e-05 - mae: 0.0035 - val_loss: 3.2603e-05 - val_mae: 0.0040
# Epoch 30/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.0742e-05 - mae: 0.0032 - val_loss: 4.6620e-05 - val_mae: 0.0047
# Epoch 31/100
# 7/7 [==============================] - 0s 18ms/step - loss: 2.6456e-05 - mae: 0.0036 - val_loss: 3.2713e-05 - val_mae: 0.0038
# Epoch 32/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.2720e-05 - mae: 0.0033 - val_loss: 3.4713e-05 - val_mae: 0.0039
# Epoch 33/100
# 7/7 [==============================] - 0s 19ms/step - loss: 2.0618e-05 - mae: 0.0032 - val_loss: 2.9641e-05 - val_mae: 0.0037
# Epoch 34/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.8692e-05 - mae: 0.0030 - val_loss: 3.7376e-05 - val_mae: 0.0042
# Epoch 35/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9408e-05 - mae: 0.0030 - val_loss: 2.8459e-05 - val_mae: 0.0036
# Epoch 36/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.8249e-05 - mae: 0.0030 - val_loss: 3.7670e-05 - val_mae: 0.0043
# Epoch 37/100
# 7/7 [==============================] - 0s 19ms/step - loss: 2.0328e-05 - mae: 0.0031 - val_loss: 3.3684e-05 - val_mae: 0.0040
# Epoch 38/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.7422e-05 - mae: 0.0029 - val_loss: 2.8054e-05 - val_mae: 0.0035
# Epoch 39/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.6763e-05 - mae: 0.0028 - val_loss: 2.7925e-05 - val_mae: 0.0036
# Epoch 40/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1.8265e-05 - mae: 0.0029 - val_loss: 3.0191e-05 - val_mae: 0.0037
# Epoch 41/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.9269e-05 - mae: 0.0030 - val_loss: 3.1525e-05 - val_mae: 0.0039
# Epoch 42/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.8395e-05 - mae: 0.0031 - val_loss: 3.7944e-05 - val_mae: 0.0041
# Epoch 43/100
# 7/7 [==============================] - 0s 17ms/step - loss: 2.5311e-05 - mae: 0.0035 - val_loss: 2.6664e-05 - val_mae: 0.0035
# Epoch 44/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.0970e-05 - mae: 0.0032 - val_loss: 2.6532e-05 - val_mae: 0.0036
# Epoch 45/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1.8542e-05 - mae: 0.0030 - val_loss: 3.0104e-05 - val_mae: 0.0037
# Epoch 46/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.6082e-05 - mae: 0.0028 - val_loss: 3.0500e-05 - val_mae: 0.0039
# Epoch 47/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.6778e-05 - mae: 0.0029 - val_loss: 3.4001e-05 - val_mae: 0.0040
# Epoch 48/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1.5941e-05 - mae: 0.0029 - val_loss: 2.4466e-05 - val_mae: 0.0034
# Epoch 49/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.7842e-05 - mae: 0.0032 - val_loss: 3.2623e-05 - val_mae: 0.0043
# Epoch 50/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.8856e-05 - mae: 0.0032 - val_loss: 3.3296e-05 - val_mae: 0.0040
# Epoch 51/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4725e-05 - mae: 0.0028 - val_loss: 2.6254e-05 - val_mae: 0.0036
# Epoch 52/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.7485e-05 - mae: 0.0031 - val_loss: 2.4819e-05 - val_mae: 0.0033
# Epoch 53/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1.5690e-05 - mae: 0.0028 - val_loss: 3.2604e-05 - val_mae: 0.0040
# Epoch 54/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.6377e-05 - mae: 0.0030 - val_loss: 2.9615e-05 - val_mae: 0.0036
# Epoch 55/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1.6924e-05 - mae: 0.0029 - val_loss: 2.5337e-05 - val_mae: 0.0036
# Epoch 56/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.6728e-05 - mae: 0.0030 - val_loss: 2.3572e-05 - val_mae: 0.0032
# Epoch 57/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.7020e-05 - mae: 0.0029 - val_loss: 3.2300e-05 - val_mae: 0.0041
# Epoch 58/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.7825e-05 - mae: 0.0032 - val_loss: 2.4500e-05 - val_mae: 0.0033
# Epoch 59/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.5399e-05 - mae: 0.0029 - val_loss: 3.7007e-05 - val_mae: 0.0042
# Epoch 60/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.8008e-05 - mae: 0.0031 - val_loss: 2.6215e-05 - val_mae: 0.0036
# Epoch 61/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.0251e-05 - mae: 0.0031 - val_loss: 2.6863e-05 - val_mae: 0.0039
# Epoch 62/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.8849e-05 - mae: 0.0031 - val_loss: 2.6250e-05 - val_mae: 0.0038
# Epoch 63/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1.8559e-05 - mae: 0.0032 - val_loss: 2.2561e-05 - val_mae: 0.0031
# Epoch 64/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.7329e-05 - mae: 0.0029 - val_loss: 4.3138e-05 - val_mae: 0.0047
# Epoch 65/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.8401e-05 - mae: 0.0029 - val_loss: 2.6755e-05 - val_mae: 0.0035
# Epoch 66/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.4113e-05 - mae: 0.0026 - val_loss: 2.3459e-05 - val_mae: 0.0035
# Epoch 67/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.3895e-05 - mae: 0.0026 - val_loss: 2.1554e-05 - val_mae: 0.0031
# Epoch 68/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.2413e-05 - mae: 0.0025 - val_loss: 2.4363e-05 - val_mae: 0.0033
# Epoch 69/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.1657e-05 - mae: 0.0024 - val_loss: 2.1679e-05 - val_mae: 0.0031
# Epoch 70/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4038e-05 - mae: 0.0026 - val_loss: 2.4862e-05 - val_mae: 0.0035
# Epoch 71/100
# 7/7 [==============================] - 0s 18ms/step - loss: 1.3018e-05 - mae: 0.0025 - val_loss: 2.0793e-05 - val_mae: 0.0030
# Epoch 72/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1786e-05 - mae: 0.0024 - val_loss: 2.5208e-05 - val_mae: 0.0034
# Epoch 73/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1.2363e-05 - mae: 0.0025 - val_loss: 2.7359e-05 - val_mae: 0.0035
# Epoch 74/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.2990e-05 - mae: 0.0026 - val_loss: 2.1865e-05 - val_mae: 0.0032
# Epoch 75/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.4769e-05 - mae: 0.0028 - val_loss: 3.2826e-05 - val_mae: 0.0040
# Epoch 76/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.2567e-05 - mae: 0.0026 - val_loss: 2.6714e-05 - val_mae: 0.0035
# Epoch 77/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.4221e-05 - mae: 0.0026 - val_loss: 2.2792e-05 - val_mae: 0.0032
# Epoch 78/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.2038e-05 - mae: 0.0024 - val_loss: 2.5428e-05 - val_mae: 0.0037
# Epoch 79/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.2601e-05 - mae: 0.0025 - val_loss: 2.3593e-05 - val_mae: 0.0033
# Epoch 80/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.0586e-05 - mae: 0.0024 - val_loss: 1.9540e-05 - val_mae: 0.0030
# Epoch 81/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.2450e-05 - mae: 0.0026 - val_loss: 2.1252e-05 - val_mae: 0.0032
# Epoch 82/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1420e-05 - mae: 0.0026 - val_loss: 2.5908e-05 - val_mae: 0.0036
# Epoch 83/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1.1992e-05 - mae: 0.0026 - val_loss: 2.7178e-05 - val_mae: 0.0037
# Epoch 84/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.3101e-05 - mae: 0.0027 - val_loss: 2.8054e-05 - val_mae: 0.0038
# Epoch 85/100
# 7/7 [==============================] - 0s 17ms/step - loss: 1.3780e-05 - mae: 0.0029 - val_loss: 2.0952e-05 - val_mae: 0.0031
# Epoch 86/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.2117e-05 - mae: 0.0026 - val_loss: 2.2600e-05 - val_mae: 0.0036
# Epoch 87/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.9848e-05 - mae: 0.0034 - val_loss: 1.9555e-05 - val_mae: 0.0031
# Epoch 88/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9552e-05 - mae: 0.0034 - val_loss: 2.5250e-05 - val_mae: 0.0037
# Epoch 89/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1.5585e-05 - mae: 0.0029 - val_loss: 3.8367e-05 - val_mae: 0.0041
# Epoch 90/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.4821e-05 - mae: 0.0028 - val_loss: 3.2904e-05 - val_mae: 0.0042
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.3303e-05 - mae: 0.0029 - val_loss: 3.2761e-05 - val_mae: 0.0038
# Epoch 92/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1.3444e-05 - mae: 0.0026 - val_loss: 1.9491e-05 - val_mae: 0.0031
# Epoch 93/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1.2964e-05 - mae: 0.0027 - val_loss: 2.1915e-05 - val_mae: 0.0034
# Epoch 94/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6297e-05 - mae: 0.0032 - val_loss: 2.3392e-05 - val_mae: 0.0036
# Epoch 95/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.8349e-05 - mae: 0.0033 - val_loss: 2.6965e-05 - val_mae: 0.0039
# Epoch 96/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.4327e-05 - mae: 0.0029 - val_loss: 3.5270e-05 - val_mae: 0.0042
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1.2216e-05 - mae: 0.0026 - val_loss: 3.5939e-05 - val_mae: 0.0040
# Epoch 98/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.5346e-05 - mae: 0.0029 - val_loss: 2.2961e-05 - val_mae: 0.0033
# Epoch 99/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1280e-05 - mae: 0.0025 - val_loss: 2.5900e-05 - val_mae: 0.0036
# Epoch 100/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.2071e-05 - mae: 0.0025 - val_loss: 2.3434e-05 - val_mae: 0.0033

# %%
y_pred_test = model.predict(X_test_scaled)

y_pred_train = model.predict(X_train_scaled)
# Out:
# 4/4 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 3ms/step

# %%
from sklearn import metrics
print('Mean Absolute Error testing:',metrics.mean_absolute_error(y_test,y_pred_test))
print('Mean Squared Error testing:',metrics.mean_squared_error(y_test,y_pred_test))
print('Root Mean Squared Error testing:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_test)))
print()
print()
print('Mean Absolute Error training:',metrics.mean_absolute_error(y_train,y_pred_train))
print('Mean Squared Error training:',metrics.mean_squared_error(y_train,y_pred_train))
print('Root Mean Squared Error training:',np.sqrt(metrics.mean_squared_error(y_train,y_pred_train)))
# Out:
# Mean Absolute Error testing: 0.0026491415328770717
# Mean Squared Error testing: 1.1509301940056375e-05
# Root Mean Squared Error testing: 0.0033925362105740853
#
#
# Mean Absolute Error training: 0.0026443764012419914
# Mean Squared Error training: 1.3872800938387436e-05
# Root Mean Squared Error training: 0.0037246209120375506

# %%
r2_testing = metrics.r2_score(y_test,y_pred_test)
r2_training = metrics.r2_score(y_train,y_pred_train)
print('R2 score training: ', metrics.r2_score(y_test,y_pred_test))
print('R2 score testing: ', metrics.r2_score(y_train,y_pred_train))

Adjusted_R2_training = 1 - (1-r2_training)*(X_train.shape[0]-1)/(X_train.shape[0]-5-1)
Adjusted_R2_testing = 1 - (1-r2_testing)*(X_test.shape[0]-1)/(X_test.shape[0]-5-1)
print('Adjusted R2 score training : ', Adjusted_R2_training)
print('Adjusted R2 score testing : ', Adjusted_R2_testing)
# Out:
# R2 score training:  0.9935723310106007
# R2 score testing:  0.9919858784815085
# Adjusted R2 score training :  0.9918262346265585
# Adjusted R2 score testing :  0.993266251534915

# %%
# Generate the six plots
fig, axes = plt.subplots(figsize=(5,5))

# Plot the learning curve
axes.plot(history.history['loss'], label='Training Loss')
axes.plot(history.history['val_loss'], label='Testing Loss')
axes.set_title('Learning Curve')
axes.set_xlabel('Epoch')
axes.set_ylabel('Loss')
axes.legend()

# %%
# Plot the predicted vs true values for the training data
plt.scatter(y_train, y_pred_train, c='crimson')
p1 = min(min(y_pred_train),min(y_train))
p2 = max(max(y_pred_train),max(y_train))
plt.plot([p1,p2],[p1,p2],'b-')
plt.xlabel('Predicted values')
plt.ylabel('True values')
plt.title('Predicted vs True values (Training data)')
plt.show()

# Plot the predicted vs true values for the testing data
plt.scatter(y_test, y_pred_test,c='crimson')
p1 = min(min(y_pred_test),min(y_test))
p2 = max(max(y_pred_test),max(y_test))
plt.plot([p1,p2],[p1,p2],'b-')
plt.xlabel('Predicted values')
plt.ylabel('True values')
plt.title('Predicted vs True values (Testing data)')
plt.show()
# Out:
# C:\Users\divya\anaconda3\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
y_pred_train = y_pred_train.reshape(-1)
y_pred_test = y_pred_test.reshape(-1)

# %%
#Scatter for training data
# Residual plot for training data
plt.scatter(y_pred_train, y_train - y_pred_train, c='blue')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Training Data: Residual Plot")
plt.show()

# Residual plot for testing data
plt.scatter(y_pred_test, y_test - y_pred_test, c='blue')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Testing Data: Residual Plot")
plt.show()

# %%
# Histogram of residuals for training data
plt.hist(y_train - y_pred_train, bins=50, color='blue')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Training Data: Histogram of Residuals")
plt.show()

# Histogram of residuals for testing data
plt.hist(y_test - y_pred_test, bins=50, color='orange')
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Testing Data: Histogram of Residuals")
plt.show()

# %%
# Q-Q plot for training data
residuals_train = y_train - y_pred_train
scipy.stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title("Training Data: Q-Q Plot")
plt.show()

# Q-Q plot for testing data
residuals_test = y_test - y_pred_test
scipy.stats.probplot(residuals_test, dist="norm", plot=plt)
plt.title("Testing Data: Q-Q Plot")
plt.show()
